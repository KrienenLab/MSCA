# %%
import scanpy as sc
import numpy as np
import anndata as ad
import pandas as pd
from pathlib import Path
import pickle
import os
import pycisTopic
pycisTopic.__version__
# Out:
# '2.0a0'

# %%
os.chdir("/jukebox/krienen/victor/marm_hmba_atac_50k/")

# %%
with open("/jukebox/krienen/victor/marm_hmba_atac_50k/data/cistopic_obj_neuron_geosketch_50kcells_marm_subcortex.pkl", "rb") as fp:
    cistopic_obj = pickle.load(fp)

# Evaluate models
models = []
model_dir = "/jukebox/krienen/victor/marm_hmba_atac_50k/pycisTopic/neuron/outs/models/"

for file in os.listdir(model_dir):
    # Check whether file is a result from topic modelling, e.g. based on the name
    if file.endswith(".pkl"):
        file_path = os.path.join(model_dir, file)
        with open(file_path, "rb") as f:
            model = pickle.load(f)
        models.append(model)

# %%
from pycisTopic.lda_models import evaluate_models
model = evaluate_models(
    models,
    select_model = 200,
    return_model = True
    #metrics = ["Minmo_2011", "loglikelihood", "Cao_Juan_2009", "Arun_2010"]
)

# %%
cistopic_obj.add_LDA_model(model)

# %%
# Identify cell-topic clusters
from pycisTopic.clust_vis import (
    find_clusters,
    run_umap,
    run_tsne,
    plot_metadata,
    plot_topic,
    cell_topic_heatmap
)

find_clusters(
    cistopic_obj,
    target  = 'cell',
    k = 10,
    res = [0.6, 1.2, 3],
    prefix = 'pycisTopic_',
    scale = True,
    split_pattern = '___'
)

run_umap(
    cistopic_obj,
    target  = 'cell', scale=True)

run_tsne(
    cistopic_obj,
    target  = 'cell', scale=True)
# Out:
# 2025-08-11 09:46:06,956 cisTopic     INFO     Finding neighbours
# 2025-08-11 09:46:32,106 cisTopic     INFO     Running UMAP
# /jukebox/scratch/vn0027/envs/scenicplus/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# 2025-08-11 09:48:02,721 cisTopic     INFO     Running TSNE

# %%
# Add metadata to a cistopic object
adata_rna = sc.read_h5ad("/jukebox/krienen/victor/marm_hmba_atac_50k/data/rna_neuron_geosketch_50kcells_marm_subcortex.h5ad", backed='r')
metadata_rna = adata_rna.obs[['Subcortex_Class_v4', 'Subcortex_Group_v4']].copy()

# Add metadata to a cistopic object
adata_atac = sc.read_h5ad("/jukebox/krienen/victor/marm_hmba_atac_50k/data/atac_neuron_geosketch_50kcells_marm_subcortex.h5ad", backed='r')
metadata_atac = adata_atac.obs[['tsse', 'n_fragment']].copy()

cistopic_obj.add_cell_data(metadata_rna, split_pattern='___')
cistopic_obj.add_cell_data(metadata_atac, split_pattern='___')

cistopic_obj.cell_data["FRiP"] = (
    cistopic_obj.cell_data["cisTopic_nr_frag"]  # fragments that fall into consensus peaks
    / cistopic_obj.cell_data["n_fragment"]      # total fragments for the barcode
)
cistopic_obj.cell_data
# Out:
#                                     cisTopic_nr_frag cisTopic_log_nr_frag  \
# GACCTTTGTTCGGTAA-P0005_2___cisTopic            47750             4.678973
# CTAGGCGGTTATGTGG-P0005_2___cisTopic            51524              4.71201
# ACAGGATCACCACAAC-P0005_2___cisTopic            42988             4.633347
# CCGCCAACAATGAATG-P0005_2___cisTopic            22046              4.34333
# GGTTCTTGTACCAGGT-P0005_2___cisTopic            59285             4.772945
# ...                                              ...                  ...
# GATTGCGTCGGTCAGC-P0081_2___cisTopic            47741             4.678892
# TCCGGAATCGCTCCAT-P0081_2___cisTopic            43214             4.635624
# GTAGGCGAGTATGTGC-P0081_2___cisTopic             4834             3.684307
# GCTGATCCAAGCTAAA-P0081_2___cisTopic            18848             4.275265
# CTAGCGGGTCGCAATA-P0081_2___cisTopic             3416             3.533518
#
#                                     cisTopic_nr_acc cisTopic_log_nr_acc  \
# GACCTTTGTTCGGTAA-P0005_2___cisTopic           26805            4.428216
# CTAGGCGGTTATGTGG-P0005_2___cisTopic           25063            4.399033
# ACAGGATCACCACAAC-P0005_2___cisTopic           23967            4.379614
# CCGCCAACAATGAATG-P0005_2___cisTopic           12361            4.092054
# GGTTCTTGTACCAGGT-P0005_2___cisTopic           31166            4.493681
# ...                                             ...                 ...
# GATTGCGTCGGTCAGC-P0081_2___cisTopic           22985            4.361445
# TCCGGAATCGCTCCAT-P0081_2___cisTopic           20595            4.313762
# GTAGGCGAGTATGTGC-P0081_2___cisTopic            2832            3.452093
# GCTGATCCAAGCTAAA-P0081_2___cisTopic           10562            4.023746
# CTAGCGGGTCGCAATA-P0081_2___cisTopic            2020            3.305351
#
#                                     sample_id pycisTopic_leiden_10_0.6  \
# GACCTTTGTTCGGTAA-P0005_2___cisTopic  cisTopic                       28
# CTAGGCGGTTATGTGG-P0005_2___cisTopic  cisTopic                       25
# ACAGGATCACCACAAC-P0005_2___cisTopic  cisTopic                       13
# CCGCCAACAATGAATG-P0005_2___cisTopic  cisTopic                       28
# GGTTCTTGTACCAGGT-P0005_2___cisTopic  cisTopic                       28
# ...                                       ...                      ...
# GATTGCGTCGGTCAGC-P0081_2___cisTopic  cisTopic                        8
# TCCGGAATCGCTCCAT-P0081_2___cisTopic  cisTopic                        8
# GTAGGCGAGTATGTGC-P0081_2___cisTopic  cisTopic                        6
# GCTGATCCAAGCTAAA-P0081_2___cisTopic  cisTopic                       10
# CTAGCGGGTCGCAATA-P0081_2___cisTopic  cisTopic                        1
#
#                                     pycisTopic_leiden_10_1.2  \
# GACCTTTGTTCGGTAA-P0005_2___cisTopic                       36
# CTAGGCGGTTATGTGG-P0005_2___cisTopic                       35
# ACAGGATCACCACAAC-P0005_2___cisTopic                       13
# CCGCCAACAATGAATG-P0005_2___cisTopic                       36
# GGTTCTTGTACCAGGT-P0005_2___cisTopic                       36
# ...                                                      ...
# GATTGCGTCGGTCAGC-P0081_2___cisTopic                        9
# TCCGGAATCGCTCCAT-P0081_2___cisTopic                        9
# GTAGGCGAGTATGTGC-P0081_2___cisTopic                        4
# GCTGATCCAAGCTAAA-P0081_2___cisTopic                       18
# CTAGCGGGTCGCAATA-P0081_2___cisTopic                       15
#
#                                     pycisTopic_leiden_10_3 Subcortex_Class_v4  \
# GACCTTTGTTCGGTAA-P0005_2___cisTopic                     47           THM GABA
# CTAGGCGGTTATGTGG-P0005_2___cisTopic                     46           THM GABA
# ACAGGATCACCACAAC-P0005_2___cisTopic                     27           THM Glut
# CCGCCAACAATGAATG-P0005_2___cisTopic                     47           THM GABA
# GGTTCTTGTACCAGGT-P0005_2___cisTopic                     47           THM GABA
# ...                                                    ...                ...
# GATTGCGTCGGTCAGC-P0081_2___cisTopic                     10           HTH GABA
# TCCGGAATCGCTCCAT-P0081_2___cisTopic                     10           HTH Glut
# GTAGGCGAGTATGTGC-P0081_2___cisTopic                      0           THM GABA
# GCTGATCCAAGCTAAA-P0081_2___cisTopic                     26       CNU-HTH Glut
# CTAGCGGGTCGCAATA-P0081_2___cisTopic                      9                 BG
#
#                                                 Subcortex_Group_v4       tsse  \
# GACCTTTGTTCGGTAA-P0005_2___cisTopic                        RT GABA   7.887508
# CTAGGCGGTTATGTGG-P0005_2___cisTopic                        RT GABA  14.450018
# ACAGGATCACCACAAC-P0005_2___cisTopic                       VLN Glut   6.646855
# CCGCCAACAATGAATG-P0005_2___cisTopic                        RT GABA  13.410119
# GGTTCTTGTACCAGGT-P0005_2___cisTopic                        RT GABA   9.577574
# ...                                                            ...        ...
# GATTGCGTCGGTCAGC-P0081_2___cisTopic            PeV SIX6-SATB2 GABA  10.194731
# TCCGGAATCGCTCCAT-P0081_2___cisTopic           PeV-ArH PPP1R17 Glut   8.634809
# GTAGGCGAGTATGTGC-P0081_2___cisTopic                    THM-MB GABA  11.928812
# GCTGATCCAAGCTAAA-P0081_2___cisTopic  HTHtu-MPA-MeR FEZF1-ESR1 Glut   9.826509
# CTAGCGGGTCGCAATA-P0081_2___cisTopic                   VTR-HTH Glut   6.926407
#
#                                      n_fragment      FRiP
# GACCTTTGTTCGGTAA-P0005_2___cisTopic       76075   0.62767
# CTAGGCGGTTATGTGG-P0005_2___cisTopic       64946  0.793336
# ACAGGATCACCACAAC-P0005_2___cisTopic       81077  0.530212
# CCGCCAACAATGAATG-P0005_2___cisTopic       31226  0.706014
# GGTTCTTGTACCAGGT-P0005_2___cisTopic       93185  0.636208
# ...                                         ...       ...
# GATTGCGTCGGTCAGC-P0081_2___cisTopic       63229  0.755049
# TCCGGAATCGCTCCAT-P0081_2___cisTopic       57843  0.747091
# GTAGGCGAGTATGTGC-P0081_2___cisTopic        8563  0.564522
# GCTGATCCAAGCTAAA-P0081_2___cisTopic       27229  0.692203
# CTAGCGGGTCGCAATA-P0081_2___cisTopic        5594  0.610654
#
# [50000 rows x 13 columns]

# %%
plot_metadata(
    cistopic_obj,
    reduction_name='tSNE',
    variables=['Subcortex_Class_v4', 'pycisTopic_leiden_10_0.6', 'pycisTopic_leiden_10_1.2','pycisTopic_leiden_10_3','n_fragment', 'tsse'],
    target='cell',num_columns=2,
    show_legend= False,
    show_label= True, 
    text_size=5,
    dot_size=0.3,
)

# %%
# Create a dir to store the output of pycisTopic
out_dir = "plots"
os.makedirs(out_dir, exist_ok = True)

plot_metadata(
    cistopic_obj,
    reduction_name='tSNE',
    variables=['Subcortex_Class_v4'],
    target='cell',
    show_legend= False,
    show_label= True, 
    text_size=7,
    dot_size=0.3,
    figsize=(5, 5),
    save="./plots/tSNE_200topics_Class_downsample_geosketch_50kcells_nonneuron.pdf" 
)

plot_metadata(
    cistopic_obj,
    reduction_name='tSNE',
    variables=['Subcortex_Group_v4'],
    target='cell',
    show_legend= False,
    show_label= True, 
    text_size=5,
    dot_size=0.3,
    figsize=(5, 5),
    save="./plots/tSNE_200topics_Group_downsample_geosketch_50kcells_nonneuron.pdf" 
)

# %%
# Update cistopicsobject with model 
out_cistopic_path = "/jukebox/krienen/victor/marm_hmba_atac_50k/data/cistopic_obj_neuron_geosketch_50kcells_marm_subcortex.pkl"
with open(out_cistopic_path, "wb") as fh:
    pickle.dump(cistopic_obj, fh)

# %%
with open("/jukebox/krienen/victor/marm_hmba_atac_50k/data/cistopic_obj_neuron_geosketch_50kcells_marm_subcortex.pkl", "rb") as fp:
    cistopic_obj = pickle.load(fp)
cistopic_obj.cell_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 4
#       2     cistopic_obj = pickle.load(fp)
#       3 cistopic_obj.cell_data
# ----> 4 cistopic_obj.model
#
# AttributeError: 'CistopicObject' object has no attribute 'model'

# %%
plot_metadata(
    cistopic_obj,
    reduction_name='tSNE',
    variables=['Subcortex_Class_v4'],
    target='cell',
    show_legend= False,
    show_label= True, 
    text_size=5,
    dot_size=0.3,
    figsize=(5, 5),
)

# %%
cistopic_obj.region_names
# Out:
# ['chr1:135544-136045',
#  'chr1:167473-167974',
#  'chr1:262780-263281',
#  'chr1:287239-287740',
#  'chr1:289894-290395',
#  'chr1:398174-398675',
#  'chr1:404711-405212',
#  'chr1:438813-439314',
#  'chr1:449476-449977',
#  'chr1:501794-502295',
#  'chr1:512360-512861',
#  'chr1:534047-534548',
#  'chr1:553812-554313',
#  'chr1:554363-554864',
#  'chr1:553177-553678',
#  'chr1:591609-592110',
#  'chr1:596776-597277',
#  'chr1:625002-625503',
#  'chr1:638383-638884',
#  'chr1:645675-646176',
#  'chr1:650327-650828',
#  'chr1:663467-663968',
#  'chr1:686781-687282',
#  'chr1:708156-708657',
#  'chr1:727123-727624',
#  'chr1:726260-726761',
#  'chr1:761533-762034',
#  'chr1:762446-762947',
#  'chr1:772503-773004',
#  'chr1:806708-807209',
#  'chr1:811843-812344',
#  'chr1:835626-836127',
#  'chr1:845726-846227',
#  'chr1:851285-851786',
#  'chr1:850663-851164',
#  'chr1:859433-859934',
#  'chr1:862459-862960',
#  'chr1:890036-890537',
#  'chr1:890769-891270',
#  'chr1:901541-902042',
#  'chr1:907774-908275',
#  'chr1:916447-916948',
#  'chr1:935719-936220',
#  'chr1:942340-942841',
#  'chr1:948189-948690',
#  'chr1:1007975-1008476',
#  'chr1:1016926-1017427',
#  'chr1:1016412-1016913',
#  'chr1:1022480-1022981',
#  'chr1:1034481-1034982',
#  'chr1:1059265-1059766',
#  'chr1:1062827-1063328',
#  'chr1:1087587-1088088',
#  'chr1:1086945-1087446',
#  'chr1:1174587-1175088',
#  'chr1:1182014-1182515',
#  'chr1:1194362-1194863',
#  'chr1:1243172-1243673',
#  'chr1:1243887-1244388',
#  'chr1:1245987-1246488',
#  'chr1:1247570-1248071',
#  'chr1:1274828-1275329',
#  'chr1:1278639-1279140',
#  'chr1:1302611-1303112',
#  'chr1:1301985-1302486',
#  'chr1:1329839-1330340',
#  'chr1:1330671-1331172',
#  'chr1:1374058-1374559',
#  'chr1:1396708-1397209',
#  'chr1:1441728-1442229',
#  'chr1:1475415-1475916',
#  'chr1:1530504-1531005',
#  'chr1:1533087-1533588',
#  'chr1:1542794-1543295',
#  'chr1:1574112-1574613',
#  'chr1:1606879-1607380',
#  'chr1:1651710-1652211',
#  'chr1:1681768-1682269',
#  'chr1:1698695-1699196',
#  'chr1:1714425-1714926',
#  'chr1:1721860-1722361',
#  'chr1:1740444-1740945',
#  'chr1:1739426-1739927',
#  'chr1:1748412-1748913',
#  'chr1:1748917-1749418',
#  'chr1:1790120-1790621',
#  'chr1:1876646-1877147',
#  'chr1:1914627-1915128',
#  'chr1:1935315-1935816',
#  'chr1:1958271-1958772',
#  'chr1:1975930-1976431',
#  'chr1:1980818-1981319',
#  'chr1:1986576-1987077',
#  'chr1:2008476-2008977',
#  'chr1:2011072-2011573',
#  'chr1:2032328-2032829',
#  'chr1:2033241-2033742',
#  'chr1:2079216-2079717',
#  'chr1:2099717-2100218',
#  'chr1:2120755-2121256',
#  'chr1:2119784-2120285',
#  'chr1:2135195-2135696',
#  'chr1:2151723-2152224',
#  'chr1:2157710-2158211',
#  'chr1:2191743-2192244',
#  'chr1:2260900-2261401',
#  'chr1:2299942-2300443',
#  'chr1:2299311-2299812',
#  'chr1:2317487-2317988',
#  'chr1:2319142-2319643',
#  'chr1:2325622-2326123',
#  'chr1:2367792-2368293',
#  'chr1:2371199-2371700',
#  'chr1:2388182-2388683',
#  'chr1:2434954-2435455',
#  'chr1:2498712-2499213',
#  'chr1:2530514-2531015',
#  'chr1:2550173-2550674',
#  'chr1:2554243-2554744',
#  'chr1:2579858-2580359',
#  'chr1:2628942-2629443',
#  'chr1:2697135-2697636',
#  'chr1:2708389-2708890',
#  'chr1:2729758-2730259',
#  'chr1:2748684-2749185',
#  'chr1:2749802-2750303',
#  'chr1:2749200-2749701',
#  'chr1:2764946-2765447',
#  'chr1:2800514-2801015',
#  'chr1:2809637-2810138',
#  'chr1:2832927-2833428',
#  'chr1:2838224-2838725',
#  'chr1:2845656-2846157',
#  'chr1:2873103-2873604',
#  'chr1:2876608-2877109',
#  'chr1:2883876-2884377',
#  'chr1:2898742-2899243',
#  'chr1:2903400-2903901',
#  'chr1:2916244-2916745',
#  'chr1:2920856-2921357',
#  'chr1:2924749-2925250',
#  'chr1:2926576-2927077',
#  'chr1:2927581-2928082',
#  'chr1:2928155-2928656',
#  'chr1:2929151-2929652',
#  'chr1:2933035-2933536',
#  'chr1:2935336-2935837',
#  'chr1:2951215-2951716',
#  'chr1:2953350-2953851',
#  'chr1:2970076-2970577',
#  'chr1:2969575-2970076',
#  'chr1:3029290-3029791',
#  'chr1:3046674-3047175',
#  'chr1:3047215-3047716',
#  'chr1:3054954-3055455',
#  'chr1:3054166-3054667',
#  'chr1:3057146-3057647',
#  'chr1:3084372-3084873',
#  'chr1:3106850-3107351',
#  'chr1:3117298-3117799',
#  'chr1:3130819-3131320',
#  'chr1:3149716-3150217',
#  'chr1:3159398-3159899',
#  'chr1:3165440-3165941',
#  'chr1:3169260-3169761',
#  'chr1:3180379-3180880',
#  'chr1:3182820-3183321',
#  'chr1:3220412-3220913',
#  'chr1:3221433-3221934',
#  'chr1:3233924-3234425',
#  'chr1:3240897-3241398',
#  'chr1:3241846-3242347',
#  'chr1:3255918-3256419',
#  'chr1:3283224-3283725',
#  'chr1:3333001-3333502',
#  'chr1:3336985-3337486',
#  'chr1:3341070-3341571',
#  'chr1:3352840-3353341',
#  'chr1:3370906-3371407',
#  'chr1:3370292-3370793',
#  'chr1:3377484-3377985',
#  'chr1:3375875-3376376',
#  'chr1:3389685-3390186',
#  'chr1:3393646-3394147',
#  'chr1:3413117-3413618',
#  'chr1:3454433-3454934',
#  'chr1:3458995-3459496',
#  'chr1:3527694-3528195',
#  'chr1:3587169-3587670',
#  'chr1:3642736-3643237',
#  'chr1:3686262-3686763',
#  'chr1:3705189-3705690',
#  'chr1:3707962-3708463',
#  'chr1:3708741-3709242',
#  'chr1:3725286-3725787',
#  'chr1:3730556-3731057',
#  'chr1:3783001-3783502',
#  'chr1:3787606-3788107',
#  'chr1:3823128-3823629',
#  'chr1:3828361-3828862',
#  'chr1:3858790-3859291',
#  'chr1:3885400-3885901',
#  'chr1:3913802-3914303',
#  'chr1:3914391-3914892',
#  'chr1:3931412-3931913',
#  'chr1:3947924-3948425',
#  'chr1:3991702-3992203',
#  'chr1:4022687-4023188',
#  'chr1:4033935-4034436',
#  'chr1:4033336-4033837',
#  'chr1:4075440-4075941',
#  'chr1:4171716-4172217',
#  'chr1:4277772-4278273',
#  'chr1:4286446-4286947',
#  'chr1:4294427-4294928',
#  'chr1:4330058-4330559',
#  'chr1:4334339-4334840',
#  'chr1:4350934-4351435',
#  'chr1:4419348-4419849',
#  'chr1:4467630-4468131',
#  'chr1:4484545-4485046',
#  'chr1:4499725-4500226',
#  'chr1:4507942-4508443',
#  'chr1:4526623-4527124',
#  'chr1:4529398-4529899',
#  'chr1:4528790-4529291',
#  'chr1:4560187-4560688',
#  'chr1:4564257-4564758',
#  'chr1:4587301-4587802',
#  'chr1:4598434-4598935',
#  'chr1:4659649-4660150',
#  'chr1:4669259-4669760',
#  'chr1:4754868-4755369',
#  'chr1:4777725-4778226',
#  'chr1:4780722-4781223',
#  'chr1:4781913-4782414',
#  'chr1:4795574-4796075',
#  'chr1:4860410-4860911',
#  'chr1:4870795-4871296',
#  'chr1:4893982-4894483',
#  'chr1:4985683-4986184',
#  'chr1:5010571-5011072',
#  'chr1:5013206-5013707',
#  'chr1:5015318-5015819',
#  'chr1:5064188-5064689',
#  'chr1:5065200-5065701',
#  'chr1:5068344-5068845',
#  'chr1:5151024-5151525',
#  'chr1:5164824-5165325',
#  'chr1:5167720-5168221',
#  'chr1:5210828-5211329',
#  'chr1:5211345-5211846',
#  'chr1:5330373-5330874',
#  'chr1:5349535-5350036',
#  'chr1:5368897-5369398',
#  'chr1:5374301-5374802',
#  'chr1:5380544-5381045',
#  'chr1:5385641-5386142',
#  'chr1:5389004-5389505',
#  'chr1:5395162-5395663',
#  'chr1:5404076-5404577',
#  'chr1:5414998-5415499',
#  'chr1:5442162-5442663',
#  'chr1:5445963-5446464',
#  'chr1:5466418-5466919',
#  'chr1:5581082-5581583',
#  'chr1:5621791-5622292',
#  'chr1:5630341-5630842',
#  'chr1:5630878-5631379',
#  'chr1:5675675-5676176',
#  'chr1:5680772-5681273',
#  'chr1:5692925-5693426',
#  'chr1:5697324-5697825',
#  'chr1:5716367-5716868',
#  'chr1:5744982-5745483',
#  'chr1:5751371-5751872',
#  'chr1:5752119-5752620',
#  'chr1:5770779-5771280',
#  'chr1:5790734-5791235',
#  'chr1:5792523-5793024',
#  'chr1:5794020-5794521',
#  'chr1:5803546-5804047',
#  'chr1:5805106-5805607',
#  'chr1:5818854-5819355',
#  'chr1:5826874-5827375',
#  'chr1:5865969-5866470',
#  'chr1:5875337-5875838',
#  'chr1:5882443-5882944',
#  'chr1:5883006-5883507',
#  'chr1:5885032-5885533',
#  'chr1:5899398-5899899',
#  'chr1:5901625-5902126',
#  'chr1:5906618-5907119',
#  'chr1:5914028-5914529',
#  'chr1:5933705-5934206',
#  'chr1:5948991-5949492',
#  'chr1:5964440-5964941',
#  'chr1:5965048-5965549',
#  'chr1:6018725-6019226',
#  'chr1:6025180-6025681',
#  'chr1:6036348-6036849',
#  'chr1:6064565-6065066',
#  'chr1:6067983-6068484',
#  'chr1:6072815-6073316',
#  'chr1:6082759-6083260',
#  'chr1:6089002-6089503',
#  'chr1:6137783-6138284',
#  'chr1:6137073-6137574',
#  'chr1:6163103-6163604',
#  'chr1:6203618-6204119',
#  'chr1:6234258-6234759',
#  'chr1:6239303-6239804',
#  'chr1:6248179-6248680',
#  'chr1:6262263-6262764',
#  'chr1:6265083-6265584',
#  'chr1:6274409-6274910',
#  'chr1:6276787-6277288',
#  'chr1:6275797-6276298',
#  'chr1:6275270-6275771',
#  'chr1:6277294-6277795',
#  'chr1:6290078-6290579',
#  'chr1:6297059-6297560',
#  'chr1:6305399-6305900',
#  'chr1:6310269-6310770',
#  'chr1:6313912-6314413',
#  'chr1:6314858-6315359',
#  'chr1:6315362-6315863',
#  'chr1:6316364-6316865',
#  'chr1:6318778-6319279',
#  'chr1:6326110-6326611',
#  'chr1:6334795-6335296',
#  'chr1:6343898-6344399',
#  'chr1:6351230-6351731',
#  'chr1:6357223-6357724',
#  'chr1:6359446-6359947',
#  'chr1:6364832-6365333',
#  'chr1:6380476-6380977',
#  'chr1:6452813-6453314',
#  'chr1:6461089-6461590',
#  'chr1:6484995-6485496',
#  'chr1:6483547-6484048',
#  'chr1:6484458-6484959',
#  'chr1:6483001-6483502',
#  'chr1:6516138-6516639',
#  'chr1:6527479-6527980',
#  'chr1:6533639-6534140',
#  'chr1:6534352-6534853',
#  'chr1:6534878-6535379',
#  'chr1:6549551-6550052',
#  'chr1:6556984-6557485',
#  'chr1:6569492-6569993',
#  'chr1:6601639-6602140',
#  'chr1:6634843-6635344',
#  'chr1:6639549-6640050',
#  'chr1:6642823-6643324',
#  'chr1:6660064-6660565',
#  'chr1:6661494-6661995',
#  'chr1:6667556-6668057',
#  'chr1:6703373-6703874',
#  'chr1:6702829-6703330',
#  'chr1:6719938-6720439',
#  'chr1:6720533-6721034',
#  'chr1:6746555-6747056',
#  'chr1:6747912-6748413',
#  'chr1:6750028-6750529',
#  'chr1:6751259-6751760',
#  'chr1:6762256-6762757',
#  'chr1:6781223-6781724',
#  'chr1:6791197-6791698',
#  'chr1:6801193-6801694',
#  'chr1:6805034-6805535',
#  'chr1:6806403-6806904',
#  'chr1:6808829-6809330',
#  'chr1:6809385-6809886',
#  'chr1:6811164-6811665',
#  'chr1:6830538-6831039',
#  'chr1:6858421-6858922',
#  'chr1:6860036-6860537',
#  'chr1:6882128-6882629',
#  'chr1:6882632-6883133',
#  'chr1:6888563-6889064',
#  'chr1:6892701-6893202',
#  'chr1:6905578-6906079',
#  'chr1:6909920-6910421',
#  'chr1:6911494-6911995',
#  'chr1:6920889-6921390',
#  'chr1:6924739-6925240',
#  'chr1:6936799-6937300',
#  'chr1:6939409-6939910',
#  'chr1:6946805-6947306',
#  'chr1:6947510-6948011',
#  'chr1:6955439-6955940',
#  'chr1:6959513-6960014',
#  'chr1:6961562-6962063',
#  'chr1:6962399-6962900',
#  'chr1:6963353-6963854',
#  'chr1:6971815-6972316',
#  'chr1:6981271-6981772',
#  'chr1:6984501-6985002',
#  'chr1:6986832-6987333',
#  'chr1:6999699-7000200',
#  'chr1:7005494-7005995',
#  'chr1:7013260-7013761',
#  'chr1:7021806-7022307',
#  'chr1:7029864-7030365',
#  'chr1:7032799-7033300',
#  'chr1:7041947-7042448',
#  'chr1:7046259-7046760',
#  'chr1:7058039-7058540',
#  'chr1:7089976-7090477',
#  'chr1:7089116-7089617',
#  'chr1:7092222-7092723',
#  'chr1:7099672-7100173',
#  'chr1:7133657-7134158',
#  'chr1:7159339-7159840',
#  'chr1:7179346-7179847',
#  'chr1:7183672-7184173',
#  'chr1:7197421-7197922',
#  'chr1:7205430-7205931',
#  'chr1:7207032-7207533',
#  'chr1:7215793-7216294',
#  'chr1:7228885-7229386',
#  'chr1:7255507-7256008',
#  'chr1:7258934-7259435',
#  'chr1:7262539-7263040',
#  'chr1:7267864-7268365',
#  'chr1:7277442-7277943',
#  'chr1:7281500-7282001',
#  'chr1:7287655-7288156',
#  'chr1:7288747-7289248',
#  'chr1:7308634-7309135',
#  'chr1:7317322-7317823',
#  'chr1:7334578-7335079',
#  'chr1:7349581-7350082',
#  'chr1:7354663-7355164',
#  'chr1:7355305-7355806',
#  'chr1:7358921-7359422',
#  'chr1:7393776-7394277',
#  'chr1:7396185-7396686',
#  'chr1:7396839-7397340',
#  'chr1:7405539-7406040',
#  'chr1:7443009-7443510',
#  'chr1:7521318-7521819',
#  'chr1:7524014-7524515',
#  'chr1:7539803-7540304',
#  'chr1:7549709-7550210',
#  'chr1:7550225-7550726',
#  'chr1:7553417-7553918',
#  'chr1:7568071-7568572',
#  'chr1:7578252-7578753',
#  'chr1:7593134-7593635',
#  'chr1:7603462-7603963',
#  'chr1:7622724-7623225',
#  'chr1:7662047-7662548',
#  'chr1:7689360-7689861',
#  'chr1:7725315-7725816',
#  'chr1:7735767-7736268',
#  'chr1:7775824-7776325',
#  'chr1:7780336-7780837',
#  'chr1:7823992-7824493',
#  'chr1:7824510-7825011',
#  'chr1:7826459-7826960',
#  'chr1:7832926-7833427',
#  'chr1:7834034-7834535',
#  'chr1:7837042-7837543',
#  'chr1:7852238-7852739',
#  'chr1:7866760-7867261',
#  'chr1:7877743-7878244',
#  'chr1:7905726-7906227',
#  'chr1:7954475-7954976',
#  'chr1:7981038-7981539',
#  'chr1:7998289-7998790',
#  'chr1:8000652-8001153',
#  'chr1:8006559-8007060',
#  'chr1:8026618-8027119',
#  'chr1:8040945-8041446',
#  'chr1:8053460-8053961',
#  'chr1:8098240-8098741',
#  'chr1:8098752-8099253',
#  'chr1:8114752-8115253',
#  'chr1:8122666-8123167',
#  'chr1:8138284-8138785',
#  'chr1:8161602-8162103',
#  'chr1:8176917-8177418',
#  'chr1:8201208-8201709',
#  'chr1:8217838-8218339',
#  'chr1:8240780-8241281',
#  'chr1:8244245-8244746',
#  'chr1:8244747-8245248',
#  'chr1:8246088-8246589',
#  'chr1:8256789-8257290',
#  'chr1:8277242-8277743',
#  'chr1:8282992-8283493',
#  'chr1:8303327-8303828',
#  'chr1:8313635-8314136',
#  'chr1:8311918-8312419',
#  'chr1:8312448-8312949',
#  'chr1:8313101-8313602',
#  'chr1:8320847-8321348',
#  'chr1:8330534-8331035',
#  'chr1:8330033-8330534',
#  'chr1:8334264-8334765',
#  'chr1:8335277-8335778',
#  'chr1:8340559-8341060',
#  'chr1:8361046-8361547',
#  'chr1:8383710-8384211',
#  'chr1:8395356-8395857',
#  'chr1:8405872-8406373',
#  'chr1:8422614-8423115',
#  'chr1:8423416-8423917',
#  'chr1:8424106-8424607',
#  'chr1:8424630-8425131',
#  'chr1:8448031-8448532',
#  'chr1:8454077-8454578',
#  'chr1:8460342-8460843',
#  'chr1:8484318-8484819',
#  'chr1:8498197-8498698',
#  'chr1:8501836-8502337',
#  'chr1:8501301-8501802',
#  'chr1:8509417-8509918',
#  'chr1:8512258-8512759',
#  'chr1:8519768-8520269',
#  'chr1:8527641-8528142',
#  'chr1:8530279-8530780',
#  'chr1:8548318-8548819',
#  'chr1:8547621-8548122',
#  'chr1:8553109-8553610',
#  'chr1:8552597-8553098',
#  'chr1:8574046-8574547',
#  'chr1:8579762-8580263',
#  'chr1:8600879-8601380',
#  'chr1:8607263-8607764',
#  'chr1:8619197-8619698',
#  'chr1:8618505-8619006',
#  'chr1:8626167-8626668',
#  'chr1:8648213-8648714',
#  'chr1:8650178-8650679',
#  'chr1:8649662-8650163',
#  'chr1:8654113-8654614',
#  'chr1:8655924-8656425',
#  'chr1:8663007-8663508',
#  'chr1:8670884-8671385',
#  'chr1:8684355-8684856',
#  'chr1:8698058-8698559',
#  'chr1:8709376-8709877',
#  'chr1:8709922-8710423',
#  'chr1:8719566-8720067',
#  'chr1:8727637-8728138',
#  'chr1:8740509-8741010',
#  'chr1:8759240-8759741',
#  'chr1:8771999-8772500',
#  'chr1:8773849-8774350',
#  'chr1:8774602-8775103',
#  'chr1:8782477-8782978',
#  'chr1:8796631-8797132',
#  'chr1:8803166-8803667',
#  'chr1:8804108-8804609',
#  'chr1:8802556-8803057',
#  'chr1:8810247-8810748',
#  'chr1:8819666-8820167',
#  'chr1:8825624-8826125',
#  'chr1:8836696-8837197',
#  'chr1:8836179-8836680',
#  'chr1:8841097-8841598',
#  'chr1:8844986-8845487',
#  'chr1:8867338-8867839',
#  'chr1:8871402-8871903',
#  'chr1:8881581-8882082',
#  'chr1:8886894-8887395',
#  'chr1:8888894-8889395',
#  'chr1:8892129-8892630',
#  'chr1:8895838-8896339',
#  'chr1:8904703-8905204',
#  'chr1:8936931-8937432',
#  'chr1:8941949-8942450',
#  'chr1:8940110-8940611',
#  'chr1:8953656-8954157',
#  'chr1:8966824-8967325',
#  'chr1:8969858-8970359',
#  'chr1:8970558-8971059',
#  'chr1:8969221-8969722',
#  'chr1:8968098-8968599',
#  'chr1:8971711-8972212',
#  'chr1:8980988-8981489',
#  'chr1:9009892-9010393',
#  'chr1:9022100-9022601',
#  'chr1:9035129-9035630',
#  'chr1:9041604-9042105',
#  'chr1:9042428-9042929',
#  'chr1:9057190-9057691',
#  'chr1:9060828-9061329',
#  'chr1:9095462-9095963',
#  'chr1:9096313-9096814',
#  'chr1:9094925-9095426',
#  'chr1:9109901-9110402',
#  'chr1:9114303-9114804',
#  'chr1:9116907-9117408',
#  'chr1:9118022-9118523',
#  'chr1:9119140-9119641',
#  'chr1:9140964-9141465',
#  'chr1:9141534-9142035',
#  'chr1:9148652-9149153',
#  'chr1:9147709-9148210',
#  'chr1:9150022-9150523',
#  'chr1:9160015-9160516',
#  'chr1:9161627-9162128',
#  'chr1:9170631-9171132',
#  'chr1:9172511-9173012',
#  'chr1:9175559-9176060',
#  'chr1:9188719-9189220',
#  'chr1:9192826-9193327',
#  'chr1:9196376-9196877',
#  'chr1:9200778-9201279',
#  'chr1:9206528-9207029',
#  'chr1:9212755-9213256',
#  'chr1:9217874-9218375',
#  'chr1:9219268-9219769',
#  'chr1:9219776-9220277',
#  'chr1:9227369-9227870',
#  'chr1:9231994-9232495',
#  'chr1:9237713-9238214',
#  'chr1:9238878-9239379',
#  'chr1:9244781-9245282',
#  'chr1:9243762-9244263',
#  'chr1:9245324-9245825',
#  'chr1:9245861-9246362',
#  'chr1:9258803-9259304',
#  'chr1:9266422-9266923',
#  'chr1:9274353-9274854',
#  'chr1:9277569-9278070',
#  'chr1:9279477-9279978',
#  'chr1:9285344-9285845',
#  'chr1:9288981-9289482',
#  'chr1:9301319-9301820',
#  'chr1:9318645-9319146',
#  'chr1:9327483-9327984',
#  'chr1:9329642-9330143',
#  'chr1:9333251-9333752',
#  'chr1:9338847-9339348',
#  'chr1:9339376-9339877',
#  'chr1:9344059-9344560',
#  'chr1:9342503-9343004',
#  'chr1:9357060-9357561',
#  'chr1:9360590-9361091',
#  'chr1:9365840-9366341',
#  'chr1:9376508-9377009',
#  'chr1:9386776-9387277',
#  'chr1:9387869-9388370',
#  'chr1:9389487-9389988',
#  'chr1:9404313-9404814',
#  'chr1:9408773-9409274',
#  'chr1:9411189-9411690',
#  'chr1:9411812-9412313',
#  'chr1:9415645-9416146',
#  'chr1:9422705-9423206',
#  'chr1:9429063-9429564',
#  'chr1:9428538-9429039',
#  'chr1:9441266-9441767',
#  'chr1:9444114-9444615',
#  'chr1:9443239-9443740',
#  'chr1:9449426-9449927',
#  'chr1:9460877-9461378',
#  'chr1:9468615-9469116',
#  'chr1:9475059-9475560',
#  'chr1:9483970-9484471',
#  'chr1:9486907-9487408',
#  'chr1:9487582-9488083',
#  'chr1:9490713-9491214',
#  'chr1:9507511-9508012',
#  'chr1:9508376-9508877',
#  'chr1:9515431-9515932',
#  'chr1:9523472-9523973',
#  'chr1:9526126-9526627',
#  'chr1:9530877-9531378',
#  'chr1:9542992-9543493',
#  'chr1:9546712-9547213',
#  'chr1:9567696-9568197',
#  'chr1:9575266-9575767',
#  'chr1:9578162-9578663',
#  'chr1:9576879-9577380',
#  'chr1:9584582-9585083',
#  'chr1:9590735-9591236',
#  'chr1:9628432-9628933',
#  'chr1:9635521-9636022',
#  'chr1:9636029-9636530',
#  'chr1:9634735-9635236',
#  'chr1:9657029-9657530',
#  'chr1:9662348-9662849',
#  'chr1:9667656-9668157',
#  'chr1:9670064-9670565',
#  'chr1:9680539-9681040',
#  'chr1:9679793-9680294',
#  'chr1:9679159-9679660',
#  'chr1:9681455-9681956',
#  'chr1:9687281-9687782',
#  'chr1:9687805-9688306',
#  'chr1:9686778-9687279',
#  'chr1:9693441-9693942',
#  'chr1:9695074-9695575',
#  'chr1:9702169-9702670',
#  'chr1:9705049-9705550',
#  'chr1:9704485-9704986',
#  'chr1:9727583-9728084',
#  'chr1:9747191-9747692',
#  'chr1:9745361-9745862',
#  'chr1:9788443-9788944',
#  'chr1:9789093-9789594',
#  'chr1:9789685-9790186',
#  'chr1:9790685-9791186',
#  'chr1:9792674-9793175',
#  'chr1:9794234-9794735',
#  'chr1:9793245-9793746',
#  'chr1:9797145-9797646',
#  'chr1:9799344-9799845',
#  'chr1:9798427-9798928',
#  'chr1:9797893-9798394',
#  'chr1:9847013-9847514',
#  'chr1:9876640-9877141',
#  'chr1:9887066-9887567',
#  'chr1:9888463-9888964',
#  'chr1:9889062-9889563',
#  'chr1:9891975-9892476',
#  'chr1:9892569-9893070',
#  'chr1:9910469-9910970',
#  'chr1:9914711-9915212',
#  'chr1:9918790-9919291',
#  'chr1:9918262-9918763',
#  'chr1:9919327-9919828',
#  'chr1:9921624-9922125',
#  'chr1:9922505-9923006',
#  'chr1:9948090-9948591',
#  'chr1:9949869-9950370',
#  'chr1:9953324-9953825',
#  'chr1:9954659-9955160',
#  'chr1:9963174-9963675',
#  'chr1:9977689-9978190',
#  'chr1:9998682-9999183',
#  'chr1:9998162-9998663',
#  'chr1:10002633-10003134',
#  'chr1:10020197-10020698',
#  'chr1:10027153-10027654',
#  'chr1:10029277-10029778',
#  'chr1:10040753-10041254',
#  'chr1:10052173-10052674',
#  'chr1:10051623-10052124',
#  'chr1:10052695-10053196',
#  'chr1:10058068-10058569',
#  'chr1:10086739-10087240',
#  'chr1:10088612-10089113',
#  'chr1:10087866-10088367',
#  'chr1:10087315-10087816',
#  'chr1:10104123-10104624',
#  'chr1:10118679-10119180',
#  'chr1:10119387-10119888',
#  'chr1:10124300-10124801',
#  'chr1:10144654-10145155',
#  'chr1:10160149-10160650',
#  'chr1:10161473-10161974',
#  'chr1:10165206-10165707',
#  'chr1:10181650-10182151',
#  'chr1:10181139-10181640',
#  'chr1:10199206-10199707',
#  'chr1:10215485-10215986',
#  'chr1:10217532-10218033',
#  'chr1:10232351-10232852',
#  'chr1:10234759-10235260',
#  'chr1:10240588-10241089',
#  'chr1:10249259-10249760',
#  'chr1:10250061-10250562',
#  'chr1:10266486-10266987',
#  'chr1:10270438-10270939',
#  'chr1:10273016-10273517',
#  'chr1:10275020-10275521',
#  'chr1:10274445-10274946',
#  'chr1:10284928-10285429',
#  'chr1:10291551-10292052',
#  'chr1:10294288-10294789',
#  'chr1:10303789-10304290',
#  'chr1:10307567-10308068',
#  'chr1:10308897-10309398',
#  'chr1:10321748-10322249',
#  'chr1:10325829-10326330',
#  'chr1:10327683-10328184',
#  'chr1:10334755-10335256',
#  'chr1:10335328-10335829',
#  'chr1:10342857-10343358',
#  'chr1:10344725-10345226',
#  'chr1:10352145-10352646',
#  'chr1:10353301-10353802',
#  'chr1:10357518-10358019',
#  'chr1:10358031-10358532',
#  'chr1:10362699-10363200',
#  'chr1:10363204-10363705',
#  'chr1:10384439-10384940',
#  'chr1:10383932-10384433',
#  'chr1:10386639-10387140',
#  'chr1:10389659-10390160',
#  'chr1:10389011-10389512',
#  'chr1:10390262-10390763',
#  'chr1:10392762-10393263',
#  'chr1:10403953-10404454',
#  'chr1:10420568-10421069',
#  'chr1:10423710-10424211',
#  'chr1:10428875-10429376',
#  'chr1:10434078-10434579',
#  'chr1:10444213-10444714',
#  'chr1:10454642-10455143',
#  'chr1:10457843-10458344',
#  'chr1:10463408-10463909',
#  'chr1:10484702-10485203',
#  'chr1:10500291-10500792',
#  'chr1:10501097-10501598',
#  'chr1:10507797-10508298',
#  'chr1:10509804-10510305',
#  'chr1:10520953-10521454',
#  'chr1:10529410-10529911',
#  'chr1:10542318-10542819',
#  'chr1:10548711-10549212',
#  'chr1:10569114-10569615',
#  'chr1:10585726-10586227',
#  'chr1:10588074-10588575',
#  'chr1:10586522-10587023',
#  'chr1:10609366-10609867',
#  'chr1:10613042-10613543',
#  'chr1:10623290-10623791',
#  'chr1:10635840-10636341',
#  'chr1:10641722-10642223',
#  'chr1:10653616-10654117',
#  'chr1:10658139-10658640',
#  'chr1:10656125-10656626',
#  'chr1:10657598-10658099',
#  'chr1:10660742-10661243',
#  'chr1:10666283-10666784',
#  'chr1:10676592-10677093',
#  'chr1:10680329-10680830',
#  'chr1:10683239-10683740',
#  'chr1:10685577-10686078',
#  'chr1:10692536-10693037',
#  'chr1:10696146-10696647',
#  'chr1:10701690-10702191',
#  'chr1:10704187-10704688',
#  'chr1:10712604-10713105',
#  'chr1:10719019-10719520',
#  'chr1:10719655-10720156',
#  'chr1:10722274-10722775',
#  'chr1:10721327-10721828',
#  'chr1:10757250-10757751',
#  'chr1:10756382-10756883',
#  'chr1:10758041-10758542',
#  'chr1:10774587-10775088',
#  'chr1:10814393-10814894',
#  'chr1:10813306-10813807',
#  'chr1:10828641-10829142',
#  'chr1:10829863-10830364',
#  'chr1:10839366-10839867',
#  'chr1:10837585-10838086',
#  'chr1:10845705-10846206',
#  'chr1:10841936-10842437',
#  'chr1:10848279-10848780',
#  'chr1:10859355-10859856',
#  'chr1:10932436-10932937',
#  'chr1:10937582-10938083',
#  'chr1:10977401-10977902',
#  'chr1:10977933-10978434',
#  'chr1:10984378-10984879',
#  'chr1:11040892-11041393',
#  'chr1:11059876-11060377',
#  'chr1:11071391-11071892',
#  'chr1:11070717-11071218',
#  'chr1:11085830-11086331',
#  'chr1:11085205-11085706',
#  'chr1:11104558-11105059',
#  'chr1:11126595-11127096',
#  'chr1:11129241-11129742',
#  'chr1:11129778-11130279',
#  'chr1:11130636-11131137',
#  'chr1:11141542-11142043',
#  'chr1:11148182-11148683',
#  'chr1:11169859-11170360',
#  'chr1:11171120-11171621',
#  'chr1:11195195-11195696',
#  'chr1:11199417-11199918',
#  'chr1:11202350-11202851',
#  'chr1:11219912-11220413',
#  'chr1:11219210-11219711',
#  'chr1:11223730-11224231',
#  'chr1:11230887-11231388',
#  'chr1:11233684-11234185',
#  'chr1:11234198-11234699',
#  'chr1:11241068-11241569',
#  'chr1:11260900-11261401',
#  'chr1:11261497-11261998',
#  'chr1:11260386-11260887',
#  'chr1:11262389-11262890',
#  'chr1:11264850-11265351',
#  'chr1:11270531-11271032',
#  'chr1:11269802-11270303',
#  'chr1:11285663-11286164',
#  'chr1:11287418-11287919',
#  'chr1:11291811-11292312',
#  'chr1:11300469-11300970',
#  'chr1:11303780-11304281',
#  'chr1:11321718-11322219',
#  'chr1:11327901-11328402',
#  'chr1:11329748-11330249',
#  'chr1:11343576-11344077',
#  'chr1:11353769-11354270',
#  'chr1:11363238-11363739',
#  'chr1:11365040-11365541',
#  'chr1:11368121-11368622',
#  'chr1:11376668-11377169',
#  'chr1:11378161-11378662',
#  'chr1:11385418-11385919',
#  'chr1:11390423-11390924',
#  'chr1:11387409-11387910',
#  'chr1:11387927-11388428',
#  'chr1:11409039-11409540',
#  'chr1:11416754-11417255',
#  'chr1:11419352-11419853',
#  'chr1:11439510-11440011',
#  'chr1:11449238-11449739',
#  'chr1:11460115-11460616',
#  'chr1:11459291-11459792',
#  'chr1:11462730-11463231',
#  'chr1:11463268-11463769',
#  'chr1:11462079-11462580',
#  'chr1:11464776-11465277',
#  'chr1:11467095-11467596',
#  'chr1:11471316-11471817',
#  'chr1:11473507-11474008',
#  'chr1:11483923-11484424',
#  'chr1:11507995-11508496',
#  'chr1:11519899-11520400',
#  'chr1:11521658-11522159',
#  'chr1:11529719-11530220',
#  'chr1:11530282-11530783',
#  'chr1:11538057-11538558',
#  'chr1:11540193-11540694',
#  'chr1:11539489-11539990',
#  'chr1:11546522-11547023',
#  'chr1:11561881-11562382',
#  'chr1:11570311-11570812',
#  'chr1:11577688-11578189',
#  'chr1:11579939-11580440',
#  'chr1:11582099-11582600',
#  'chr1:11584447-11584948',
#  'chr1:11588898-11589399',
#  'chr1:11595378-11595879',
#  'chr1:11594794-11595295',
#  'chr1:11600316-11600817',
#  'chr1:11630193-11630694',
#  'chr1:11655164-11655665',
#  'chr1:11658825-11659326',
#  'chr1:11672968-11673469',
#  'chr1:11671826-11672327',
#  'chr1:11675330-11675831',
#  'chr1:11677211-11677712',
#  'chr1:11676707-11677208',
#  'chr1:11685160-11685661',
#  'chr1:11692752-11693253',
#  'chr1:11701769-11702270',
#  'chr1:11713278-11713779',
#  'chr1:11719147-11719648',
#  'chr1:11719764-11720265',
#  'chr1:11724371-11724872',
#  'chr1:11723762-11724263',
#  'chr1:11729897-11730398',
#  'chr1:11743782-11744283',
#  'chr1:11751626-11752127',
#  'chr1:11761467-11761968',
#  'chr1:11762056-11762557',
#  'chr1:11759116-11759617',
#  'chr1:11786091-11786592',
#  'chr1:11787309-11787810',
#  'chr1:11789804-11790305',
#  'chr1:11793414-11793915',
#  'chr1:11807586-11808087',
#  'chr1:11805850-11806351',
#  'chr1:11811273-11811774',
#  'chr1:11812403-11812904',
#  'chr1:11821012-11821513',
#  'chr1:11833218-11833719',
#  'chr1:11837015-11837516',
#  'chr1:11849808-11850309',
#  'chr1:11850435-11850936',
#  'chr1:11857835-11858336',
#  'chr1:11856952-11857453',
#  'chr1:11861595-11862096',
#  'chr1:11883485-11883986',
#  'chr1:11896431-11896932',
#  'chr1:11897915-11898416',
#  'chr1:11898682-11899183',
#  'chr1:11914827-11915328',
#  'chr1:11919271-11919772',
#  'chr1:11932823-11933324',
#  'chr1:11937339-11937840',
#  'chr1:11938736-11939237',
#  'chr1:11943437-11943938',
#  'chr1:11942793-11943294',
#  'chr1:11945150-11945651',
#  ...]

# %%
# !pwd
# Out:
# /mnt/cup/labs/krienen/victor/marm_hmba_atac_50k

# %%
with open("/jukebox/krienen/victor/marm_hmba_atac_50k/data/marm_subcortex_filtered_peaks.txt", "w") as f:
    for region in cistopic_obj.region_names:
        f.write(region + "\n")

#awk -F '[:-]' '{print $1 "\t" $2 "\t" $3}' /jukebox/krienen/victor/marm_hmba_atac_50k/data/marm_subcortex_filtered_peaks.txt > /jukebox/krienen/victor/marm_hmba_atac_50k/data/marm_subcortex_filtered_peaks.bed

# %%
'''# names you want to exclude
exclude_groups = ["Nonneuron", "Junk"]

# get cell barcodes we want to keep
keep_cells = (
    cistopic_obj.cell_data
    .query("Subcortex_Group_v4 not in @exclude_groups ")      # fast, readable
    .index
)

# subset the whole object in one call
cistopic_obj = cistopic_obj.subset(cells=keep_cells) '''
cistopic_obj.cell_data['Subcortex_Class_v4'] = cistopic_obj.cell_data['Subcortex_Class_v4'].astype(str)

# %%
'''exclude = {'nan'}
clean_group_labels = [
    v for v in cistopic_obj.cell_data['Subcortex_Class_v4'].dropna().unique()
    if v not in exclude
]
clean_group_labels'''

cell_topic_heatmap(
    cistopic_obj,
    variables = ['Subcortex_Class_v4'],
    scale = True,
    legend_loc_x = 1.0,
    legend_loc_y = -1.2,
    legend_dist_y = -1,
    figsize = (10, 10),
    save="./plots/cell_topic_heatmap_200topics_Class_downsample_geosketch_50kcells_neuron.pdf" 
)

# %%
cistopic_obj.cell_data['Subcortex_Group_v4'] = cistopic_obj.cell_data['Subcortex_Group_v4'].astype(str)

# %%
cell_topic_heatmap(
    cistopic_obj,
    variables = ['Subcortex_Group_v4'],
    scale = True,
    legend_loc_x = 1.0,
    legend_loc_y = -1.2,
    legend_dist_y = -1,
    figsize = (10, 10),
    save="./plots/cell_topic_heatmap_200topics_Group_downsample_geosketch_50kcells_neuron.pdf" 
)

# %%
from pycisTopic.topic_binarization import binarize_topics

region_bin_topics_top_3k = binarize_topics(
    cistopic_obj, method='ntop', ntop = 3_000,
    plot=False
)

binarized_cell_topic = binarize_topics(
    cistopic_obj,
    target='cell',
    method='li',
    plot=False
)

from pycisTopic.topic_qc import compute_topic_metrics, plot_topic_qc, topic_annotation
import matplotlib.pyplot as plt
from pycisTopic.utils import fig2img

topic_qc_metrics = compute_topic_metrics(cistopic_obj)

# %%
#AssignmentsVSCells_in_bin
plot_topic_qc(topic_qc_metrics, var_x='Log10_Assignments', var_y='Cells_in_binarized_topic', var_color='Gini_index',
    dot_size=50,
    text_size=6,
    plot=True,
    save="./plots/AssignmentsVSCells_in_bin_200topics_Group_v4_geosketch_50kcells_neuron.pdf" )

#CoherenceVSMarginal_dist
plot_topic_qc(topic_qc_metrics, var_x='Coherence', var_y='Marginal_topic_dist', var_color='Gini_index',
    dot_size=50,
    text_size=6,
    plot=True,
    save="./plots/CoherenceVSMarginal_dist_200topics_Group_v4_geosketch_50kcells_neuron.pdf" )

# %%
topic_annot = topic_annotation(
    cistopic_obj,
    annot_var='Subcortex_Group_v4',
    binarized_cell_topic=binarized_cell_topic,
    general_topic_thr = 0.2
)
topic_annot
# Out:
#          Subcortex_Group_v4 Ratio_cells_in_topic Ratio_group_in_population  \
# Topic1                                  0.053454                       0.0
# Topic2                                  0.239072                       0.0
# Topic3                                  0.028574                       0.0
# Topic4                                    0.0827                       0.0
# Topic5                                  0.042431                       0.0
# ...                     ...                  ...                       ...
# Topic196                                0.053727                       0.0
# Topic197                                0.010204                       0.0
# Topic198                                0.142935                       0.0
# Topic199                                0.073672                       0.0
# Topic200                                0.018035                       0.0
#
#           is_general
# Topic1         False
# Topic2          True
# Topic3         False
# Topic4         False
# Topic5         False
# ...              ...
# Topic196       False
# Topic197       False
# Topic198       False
# Topic199       False
# Topic200       False
#
# [200 rows x 4 columns]

# %%
# Save cistopicsobject with model and topic binarization
out_cistopic_path = "/jukebox/krienen/victor/marm_hmba_atac_downsampled/data/cistopic_obj_geosketch_50kcells_marm_subcortex_neuron.pkl"
with open(out_cistopic_path, "wb") as fh:
    pickle.dump(cistopic_obj, fh)
